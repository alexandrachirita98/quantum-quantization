# %% [markdown]
# # Training Pipeline — Control QCNN (U2)
#
# A **Multi-Channel Quantum Convolutional Neural Network** (Control baseline), ported from
# [`anthonysmaldone/QCNN-Multi-Channel-Supervised-Learning`](https://github.com/anthonysmaldone/QCNN-Multi-Channel-Supervised-Learning)
# (Smaldone & Batista, *Hardware-adaptable quantum circuits for convolutional layers with
# multi-channel data*, Quantum Machine Intelligence, 2023,
# [doi:10.1007/s42484-023-00130-3](https://doi.org/10.1007/s42484-023-00130-3)). Like
# [`qcnn.ipynb`](./qcnn.ipynb) and [`quonv.ipynb`](./quonv.ipynb), there is no
# PennyLane/TensorFlow-Quantum dependency here — the load-bearing circuit is ported as plain `torch`
# tensor ops in [`cnn/models/mcqcnn.py`](../../models/mcqcnn.py).
#
# Trained and evaluated on **BreastMNIST**, matching every other notebook in this folder — same
# dataset, same [`_handlers/evaluation.py::evaluate_all_metrics`](../../../_handlers/evaluation.py)
# metric suite, so all the quantum and classical runs are directly comparable.
#
# **This notebook is one of ten.** `train.py`'s menu offers ten trainable variants — five
# architectures (CO, PCO, PCO-T, WEV, control) x two circuit ansatzes (U1, U2). This folder has one
# notebook each, and they are **identical except for the single factory call in the _Model_ cell**.
#
# ## What all ten share
#
# A genuine sliding **2x2, stride-1, no-padding quantum convolution** (`extract_patches`), with
# `n_kernels=3` independently-learned parameter sets acting as three output feature maps — the
# quantum analogue of a classical `Conv2D`. Each patch's 4 pixels are `RX` angle-encoded onto 4
# qubits, an entangling schedule of **fractional powers of X and Z** (`CXPowGate`/`CZPowGate`,
# continuously interpolating identity <-> CNOT/CZ via a trainable exponent) is applied, and one
# qubit is measured. Every circuit then applies the same `arccos(clip(e)) / pi` un-embedding before
# the classical head — `Flatten` -> `Dense(32, relu)` -> `Dense(n_classes)`, exactly `models.py`.
#
# The ten differ **only in how the channels are combined**, which is the paper's entire subject.
#
# ## This variant: Control QCNN (U2)
#
# The paper's **non-multi-channel-aware baseline** — "an existing QCNN", the reference
# the other four variants are meant to beat. One fixed 4-qubit circuit per channel with private
# parameters, `PauliZ`-read on qubit 0, and the per-channel expectation values combined by a plain
# classical **sum** with nothing learned about the combination.
#
# **4 qubits** per channel-circuit (no ancilla).
#
# **U2 control circuit** (`circuits.py::Q_U2_control`) — a QCNN-style layer over the 2x2 qubit grid: a `CZPowGate` then a `CXPowGate` between pairs at increasing step sizes `1, 2`.
#
# ## The other nine
#
# | Notebook | Variant | Circuit | Qubits |
# |---|---|---|---|
# | [`mcqcnn_co_u1.ipynb`](./mcqcnn_co_u1.ipynb) | CO-QCNN (U1) | `U1Circuit(registers=1)` | 5 |
# | [`mcqcnn_pco_u1.ipynb`](./mcqcnn_pco_u1.ipynb) | PCO-QCNN (U1) | `U1Circuit(registers=3, rdpa=3, inter_U=True)` | 13 |
# | [`mcqcnn_pco_t_u1.ipynb`](./mcqcnn_pco_t_u1.ipynb) | PCO-T-QCNN (U1) | `U1Circuit(registers=3, rdpa=1, inter_U=True)` | 15 |
# | [`mcqcnn_wev_u1.ipynb`](./mcqcnn_wev_u1.ipynb) | WEV-QCNN (U1) | `QU1Control(classical_weights=True)` | 4 |
# | [`mcqcnn_control_u1.ipynb`](./mcqcnn_control_u1.ipynb) | Control QCNN (U1) | `QU1Control()` | 4 |
# | [`mcqcnn_co_u2.ipynb`](./mcqcnn_co_u2.ipynb) | CO-QCNN (U2) | `U2Circuit(registers=1)` | 5 |
# | [`mcqcnn_pco_u2.ipynb`](./mcqcnn_pco_u2.ipynb) | PCO-QCNN (U2) | `U2Circuit(registers=3, rdpa=3, inter_U=True)` | 13 |
# | [`mcqcnn_pco_t_u2.ipynb`](./mcqcnn_pco_t_u2.ipynb) | PCO-T-QCNN (U2) | `U2Circuit(registers=3, rdpa=1, inter_U=True)` | 15 |
# | [`mcqcnn_wev_u2.ipynb`](./mcqcnn_wev_u2.ipynb) | WEV-QCNN (U2) | `QU2Control(classical_weights=True)` | 4 |
# | [`mcqcnn_control_u2.ipynb`](./mcqcnn_control_u2.ipynb) | Control QCNN (U2) | `QU2Control()` | 4 |
#
# ## Note on the channel count
#
# BreastMNIST is grayscale, and the MC-QCNN variants only differ from each other in how they combine
# channels — a 1-channel input would collapse all ten into near-identical models. The dataset cell
# therefore replicates the single channel into 3, the same grayscale->RGB adaptation
# [`qtransfer.ipynb`](./qtransfer.ipynb) makes for ResNet18, mapping onto the original's 3-channel
# `COLORS`/`CIFAR10` path (`registers=3`). **The three channels carry identical data**, so the
# multi-channel *machinery* is exercised but the inter-channel *information* the paper's ansatzes
# are built to capture is not there to find — expect the five architectures to separate much less
# than they do in the paper. Point `args.dataset` at a natively-RGB MedMNIST flag (`bloodmnist`,
# `pathmnist`, `dermamnist`, `retinamnist`) for a run where the channels actually differ.

# %% [markdown]
# ## Install Requirements
#
# What the pipeline imports: `torch` for the model/training loop, `medmnist` for BreastMNIST,
# `scikit-learn` for the metrics, plus `tqdm`. No `tensorflow`, `tensorflow-quantum` or `cirq` — the
# circuits are reimplemented as dense `torch` tensor ops, so the original's quantum-simulation stack
# is never installed.

# %%
# !nvidia-smi
# Out:
# Tue Jul 28 15:51:06 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0             28W /   70W |     193MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   38C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A              58      C   /usr/bin/python3                        190MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch==2.5.0 in /usr/local/lib/python3.12/dist-packages (2.5.0+cu124)
# Requirement already satisfied: torchvision==0.20.0 in /usr/local/lib/python3.12/dist-packages (0.20.0+cu124)
# Requirement already satisfied: torchaudio==2.5.0 in /usr/local/lib/python3.12/dist-packages (2.5.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (81.0.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.0) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.20.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.5.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.5.0) (3.0.3)

# %%
# !pip install medmnist==3.0.2 scikit-learn tqdm requests
# Out:
# Requirement already satisfied: medmnist==3.0.2 in /usr/local/lib/python3.12/dist-packages (3.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (2.3.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (0.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (11.3.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (2.5.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from medmnist==3.0.2) (0.20.0+cu124)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->medmnist==3.0.2) (3.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist==3.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist==3.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist==3.0.2) (2026.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist==3.0.2) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist==3.0.2) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist==3.0.2) (2026.4.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist==3.0.2) (26.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist==3.0.2) (0.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (4.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (81.0.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch->medmnist==3.0.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch->medmnist==3.0.2) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->medmnist==3.0.2) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->medmnist==3.0.2) (3.0.3)

# %% [markdown]
# ## Get the survey code
#
# The model and handlers live in this repository's `survey/src/cnn` and `survey/src/_handlers`
# packages, so the notebook needs a checkout of it. On Colab it clones into
# `/content/quantum-quantization`, or `git pull --ff-only`s that directory if it is already there —
# so re-running the cell after a push picks up the new code. Run locally, the notebook already sits
# inside the repo, so `find_src` climbs to `survey/src` and git is never touched (your working tree
# is left alone).
#
# The branch is chosen by *environment*, not by working directory: the imports cell `os.chdir`s into
# the checkout, so a cwd-based test would find `cnn` on every re-run and silently skip the pull.
#
# If the repository is private the anonymous clone fails with an authentication error; use a token
# URL instead — `REPO_URL = 'https://<GITHUB_TOKEN>@github.com/alexandrachirita98/quantum-quantization.git'`.

# %%
import pathlib
import subprocess
import sys

REPO_URL = 'https://github.com/alexandrachirita98/quantum-quantization.git'

# NB: key off the environment, not the working directory. `os.chdir` in the imports cell moves the
# cwd *inside* the checkout, so a cwd-based test would report "already have the code" on every
# re-run and silently skip the pull.
IN_COLAB = 'google.colab' in sys.modules or pathlib.Path('/content').is_dir()
CLONE_DIR = pathlib.Path('/content/quantum-quantization')   # where the Colab checkout goes


def find_src(start):
    """Climb from `start` looking for the survey `src/` root — the directory holding `cnn`."""
    for p in [pathlib.Path(start), *pathlib.Path(start).parents]:
        if (p / 'cnn' / 'models' / 'mcqcnn.py').is_file():
            return p
    return None


if IN_COLAB:
    if CLONE_DIR.exists():                                  # refresh whatever was cloned earlier
        subprocess.run(['git', 'pull', '--ff-only'], cwd=str(CLONE_DIR), check=True)
    else:
        subprocess.run(['git', 'clone', REPO_URL, str(CLONE_DIR)], check=True)
    SRC = CLONE_DIR / 'survey' / 'src'
else:                                                       # local: the notebook lives in the repo
    SRC = find_src(pathlib.Path.cwd())

assert SRC is not None and (SRC / 'cnn' / 'models' / 'mcqcnn.py').is_file(), f'mcqcnn.py not found under {SRC}'
print('survey src:', SRC)
# Out:
# Already up to date.
# survey src: /content/quantum-quantization/survey/src

# %% [markdown]
# ## Imports
#
# `CONTROL_U2_QCNN` (this notebook's variant) and the training helpers come from the survey's `cnn`
# package; `evaluate_all_metrics` (the same all-metrics evaluator every classical notebook uses)
# comes from `_handlers`. `SRC` from the previous cell goes on `sys.path`, and `os.chdir` moves into
# it so `./data` (the shared [`src/data`](../../../data) folder) is where `medmnist` downloads
# BreastMNIST.

# %%
import os
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from medmnist import BreastMNIST

# import the pipeline from the survey `src/` root, and work from there so './data' resolves inside it
sys.path.insert(0, str(SRC))
os.chdir(SRC)
print('working directory:', os.getcwd())

# drop cached modules, so a `git pull` above is actually reflected on a re-run
for _m in [m for m in list(sys.modules) if m in ('cnn', '_handlers') or m.startswith(('cnn.', '_handlers.'))]:
    del sys.modules[_m]

from cnn.models.mcqcnn import CONTROL_U2_QCNN
from cnn.handlers.mcqcnn import (
    train_mcqcnn,
    evaluate,
    resize_images,
    RawImageDataset,
    MCQCNNLogits,
)
from _handlers.evaluation import evaluate_all_metrics
# Out:
# working directory: /content/quantum-quantization/survey/src

# %% [markdown]
# ## Configuration
#
# `train.py`'s shipped defaults, kept as a plain namespace instead of its interactive menu:
# `lr=0.001` (`datamenu2`'s default), Adam, sparse-categorical cross-entropy.
#
# **Image size** — `10x10`. Every model in `models.py` declares
# `tf.keras.layers.Input((10,10,C))`, so BreastMNIST's native 28x28 is bilinear-resized down to
# match. This is not cosmetic: the quantum conv slides over every patch, and 28x28 would mean 729
# patches per image instead of 81.
#
# **Dataset** — `breastmnist`, the same medmnist flag every other notebook in this folder trains on.
#
# **Batch size and epochs deviate from the original** (`50` and `20`). The heavier variants simulate
# 13- and 15-qubit statevectors for `batch_size * 81 * 3` patches at once, with autograd retaining an
# intermediate per gate — at batch 50 that is tens of gigabytes. `batch_size=4` keeps all ten
# runnable from one shared config; `epochs=5` keeps the demo run bounded, the same reduction
# [`quonv.ipynb`](./quonv.ipynb) makes. Raise both for the 4- and 5-qubit variants (CO, WEV,
# control), where memory is not a constraint.

# %%
from types import SimpleNamespace

args = SimpleNamespace(
    dataset='breastmnist',   # a medmnist flag, native 28x28 resolution
    img_size=10,             # models.py hardcodes Input((10,10,C))
    n_channels=3,            # grayscale replicated to 3, matching the original's COLORS path
    n_classes=2,             # BreastMNIST is binary (malignant vs. normal/benign)
    lr=0.001,                # train.py's default learning rate
    batch_size=4,            # original uses 50; lowered so the 15-qubit variants fit in memory
    epochs=5,                # original uses 20; kept small for a demo run
)

# %% [markdown]
# ## Device

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Using {} device.".format(device))
# Out:
# Using cuda:0 device.

# %% [markdown]
# ## Dataset
#
# BreastMNIST (malignant vs. normal/benign, already binary). Each native 28x28 image is
# bilinear-resized down to `img_size x img_size`, kept in `[0, 1]`, replicated across `n_channels`
# and returned **channel-last** as `(B, H, W, C)` — the TensorFlow layout the ported models expect,
# not PyTorch's usual `(B, C, H, W)`.
#
# `train_raw`/`test_raw` also back a `RawImageDataset` each, used only by the final evaluation cell
# below — `evaluate_all_metrics` expects a `Dataset` of raw `(image, label)` pairs and applies the
# resize itself (via `MCQCNNLogits`), the same way `quonv.ipynb` hands it raw images plus a logits
# adapter.

# %%
os.makedirs('./data', exist_ok=True)   # BreastMNIST() checks root exists *before* downloading

train_raw = BreastMNIST(split='train', download=True, root='./data')
test_raw = BreastMNIST(split='test', download=True, root='./data')

train_x = resize_images(train_raw.imgs, args.img_size, args.n_channels)
train_y = torch.from_numpy(train_raw.labels).reshape(-1).long()
test_x = resize_images(test_raw.imgs, args.img_size, args.n_channels)
test_y = torch.from_numpy(test_raw.labels).reshape(-1).long()

train_loader = data.DataLoader(data.TensorDataset(train_x, train_y), batch_size=args.batch_size, shuffle=True)
test_loader = data.DataLoader(data.TensorDataset(test_x, test_y), batch_size=args.batch_size, shuffle=False)

train_dataset = RawImageDataset(train_raw.imgs, train_raw.labels)
test_dataset = RawImageDataset(test_raw.imgs, test_raw.labels)

print('train:', train_x.shape, train_y.shape)   # (N, 10, 10, 3) channel-last
print('test: ', test_x.shape, test_y.shape)
# Out:
# Using downloaded and verified file: ./data/breastmnist.npz
# Using downloaded and verified file: ./data/breastmnist.npz
# train: torch.Size([546, 10, 10, 3]) torch.Size([546])
# test:  torch.Size([156, 10, 10, 3]) torch.Size([156])

# %% [markdown]
# ## Model
#
# **This is the only cell that differs between the ten notebooks.**
#
# `CONTROL_U2_QCNN` is this repository's port of `models.py::Control baseline` — it builds the quantum-conv layer
# described at the top, then `Flatten` -> `Dense(32, relu)` -> `Dense(n_classes)`. The softmax the
# original declares on its last layer is folded into `nn.CrossEntropyLoss` below instead, matching
# every other classical head in this codebase.
#
# Swap this call for any other name in `cnn.models.mcqcnn.VARIANTS` to turn this notebook into one
# of the other nine.

# %%
net = CONTROL_U2_QCNN(image_size=args.img_size,
                 n_input_channels=args.n_channels,
                 n_classes=args.n_classes).to(device)

print(net)
print('qubits per circuit:', net.qconv.n_qubits)
print('trainable parameters:', sum(p.numel() for p in net.parameters() if p.requires_grad))
# Out:
# MCQCNNModel(
#   (qconv): QU2Control()
#   (relu): ReLU()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=243, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=2, bias=True)
# )
# qubits per circuit: 4
# trainable parameters: 7928

# %% [markdown]
# ## Optimizer & Loss
#
# Adam at `args.lr` and `nn.CrossEntropyLoss`, matching `train.py::train_model`'s
# `model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy')`
# — PyTorch's `CrossEntropyLoss` takes integer class labels and applies the log-softmax itself, which
# is exactly what Keras's *sparse* categorical cross-entropy does on top of the model's softmax.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=args.lr)

# %% [markdown]
# ## Train
#
# `train_mcqcnn` (from the handler) runs `args.epochs` passes over the training set — `model.fit`'s
# loop — validating on the test set at the end of each epoch.
#
# Expect this to be slow for the PCO variants: every step simulates a 13- or 15-qubit statevector for
# `batch_size * 81 * 3` patches. The 4- and 5-qubit variants (CO, WEV, control) run in a fraction of
# the time.

# %%
train_mcqcnn(net, optimizer, criterion, train_loader, test_loader, device,
             epochs=args.epochs)
# Out:
# epoch 1/5  step 5  loss: 0.8400
# epoch 1/5  step 10  loss: 0.7207
# epoch 1/5  step 15  loss: 0.7893
# epoch 1/5  step 20  loss: 0.6623
# epoch 1/5  step 25  loss: 0.3057
# epoch 1/5  step 30  loss: 0.3827
# epoch 1/5  step 35  loss: 0.2280
# epoch 1/5  step 40  loss: 0.3075
# epoch 1/5  step 45  loss: 0.1299
# epoch 1/5  step 50  loss: 0.7661
# epoch 1/5  step 55  loss: 0.4978
# epoch 1/5  step 60  loss: 0.9104
# epoch 1/5  step 65  loss: 0.5071
# epoch 1/5  step 70  loss: 1.0378
# epoch 1/5  step 75  loss: 0.5284
# epoch 1/5  step 80  loss: 0.7472
# epoch 1/5  step 85  loss: 0.6648
# epoch 1/5  step 90  loss: 0.6234
# epoch 1/5  step 95  loss: 0.8986
# epoch 1/5  step 100  loss: 0.6973
# epoch 1/5  step 105  loss: 0.6699
# epoch 1/5  step 110  loss: 0.7985
# epoch 1/5  step 115  loss: 0.5511
# epoch 1/5  step 120  loss: 0.6013
# epoch 1/5  step 125  loss: 0.4036
# epoch 1/5  step 130  loss: 0.5604
# epoch 1/5  step 135  loss: 0.6216
# [epoch 1] train_loss: 0.6035  val_acc: 0.7115
# epoch 2/5  step 5  loss: 0.9579
# epoch 2/5  step 10  loss: 0.5857
# epoch 2/5  step 15  loss: 0.3485
# epoch 2/5  step 20  loss: 0.4395
# epoch 2/5  step 25  loss: 1.1652
# epoch 2/5  step 30  loss: 0.5930
# epoch 2/5  step 35  loss: 0.4737
# epoch 2/5  step 40  loss: 0.3331
# epoch 2/5  step 45  loss: 0.4692
# epoch 2/5  step 50  loss: 0.7143
# epoch 2/5  step 55  loss: 0.5527
# epoch 2/5  step 60  loss: 0.6584
# epoch 2/5  step 65  loss: 0.6576
# epoch 2/5  step 70  loss: 0.5568
# epoch 2/5  step 75  loss: 0.2641
# epoch 2/5  step 80  loss: 0.2970
# epoch 2/5  step 85  loss: 0.9134
# epoch 2/5  step 90  loss: 0.3934
# epoch 2/5  step 95  loss: 0.3991
# epoch 2/5  step 100  loss: 0.6467
# epoch 2/5  step 105  loss: 0.3769
# epoch 2/5  step 110  loss: 0.2526
# epoch 2/5  step 115  loss: 0.4305
# epoch 2/5  step 120  loss: 0.4877
# epoch 2/5  step 125  loss: 0.6601
# epoch 2/5  step 130  loss: 0.4180
# epoch 2/5  step 135  loss: 1.3273
# [epoch 2] train_loss: 0.5548  val_acc: 0.7051
# epoch 3/5  step 5  loss: 0.4562
# epoch 3/5  step 10  loss: 0.3105
# epoch 3/5  step 15  loss: 0.4681
# epoch 3/5  step 20  loss: 0.3073
# epoch 3/5  step 25  loss: 0.5825
# epoch 3/5  step 30  loss: 0.6227
# epoch 3/5  step 35  loss: 0.5329
# epoch 3/5  step 40  loss: 0.6712
# epoch 3/5  step 45  loss: 0.4114
# epoch 3/5  step 50  loss: 0.5293
# epoch 3/5  step 55  loss: 0.4079
# epoch 3/5  step 60  loss: 0.5797
# epoch 3/5  step 65  loss: 0.7468
# epoch 3/5  step 70  loss: 0.5247
# epoch 3/5  step 75  loss: 0.7058
# epoch 3/5  step 80  loss: 0.3332
# epoch 3/5  step 85  loss: 0.7101
# epoch 3/5  step 90  loss: 0.4010
# epoch 3/5  step 95  loss: 1.4279
# epoch 3/5  step 100  loss: 0.1008
# epoch 3/5  step 105  loss: 0.3863
# epoch 3/5  step 110  loss: 0.6264
# epoch 3/5  step 115  loss: 0.5457
# epoch 3/5  step 120  loss: 0.6722
# epoch 3/5  step 125  loss: 1.0789
# epoch 3/5  step 130  loss: 0.5567
# epoch 3/5  step 135  loss: 0.3817
# [epoch 3] train_loss: 0.5369  val_acc: 0.7179
# epoch 4/5  step 5  loss: 0.5369
# epoch 4/5  step 10  loss: 0.2668
# epoch 4/5  step 15  loss: 0.8822
# epoch 4/5  step 20  loss: 0.3877
# epoch 4/5  step 25  loss: 0.5080
# epoch 4/5  step 30  loss: 0.2769
# epoch 4/5  step 35  loss: 0.4626
# epoch 4/5  step 40  loss: 0.6924
# epoch 4/5  step 45  loss: 0.6046
# epoch 4/5  step 50  loss: 0.3057
# epoch 4/5  step 55  loss: 0.5634
# epoch 4/5  step 60  loss: 0.4928
# epoch 4/5  step 65  loss: 0.2606
# epoch 4/5  step 70  loss: 0.7688
# epoch 4/5  step 75  loss: 0.9668
# epoch 4/5  step 80  loss: 0.5635
# epoch 4/5  step 85  loss: 0.7686
# epoch 4/5  step 90  loss: 0.2336
# epoch 4/5  step 95  loss: 0.4097
# epoch 4/5  step 100  loss: 0.6019
# epoch 4/5  step 105  loss: 0.4249
# epoch 4/5  step 110  loss: 0.4342
# epoch 4/5  step 115  loss: 0.3172
# epoch 4/5  step 120  loss: 0.6759
# epoch 4/5  step 125  loss: 0.4674
# epoch 4/5  step 130  loss: 0.8948
# epoch 4/5  step 135  loss: 0.4017
# [epoch 4] train_loss: 0.5249  val_acc: 0.7372
# epoch 5/5  step 5  loss: 1.3725
# epoch 5/5  step 10  loss: 0.5012
# epoch 5/5  step 15  loss: 0.4193
# epoch 5/5  step 20  loss: 0.5133
# epoch 5/5  step 25  loss: 0.4857
# epoch 5/5  step 30  loss: 0.9406
# epoch 5/5  step 35  loss: 0.2156
# epoch 5/5  step 40  loss: 0.5865
# epoch 5/5  step 45  loss: 0.0958
# epoch 5/5  step 50  loss: 0.5567
# epoch 5/5  step 55  loss: 0.4202
# epoch 5/5  step 60  loss: 0.5225
# epoch 5/5  step 65  loss: 0.2068
# epoch 5/5  step 70  loss: 0.4174
# epoch 5/5  step 75  loss: 0.3153
# epoch 5/5  step 80  loss: 0.5192
# epoch 5/5  step 85  loss: 0.3628
# epoch 5/5  step 90  loss: 0.3609
# epoch 5/5  step 95  loss: 0.7101
# epoch 5/5  step 100  loss: 0.5123
# epoch 5/5  step 105  loss: 0.5073
# epoch 5/5  step 110  loss: 0.4683
# epoch 5/5  step 115  loss: 0.4765
# epoch 5/5  step 120  loss: 0.6490
# epoch 5/5  step 125  loss: 0.5784
# epoch 5/5  step 130  loss: 0.7969
# epoch 5/5  step 135  loss: 0.2136
# [epoch 5] train_loss: 0.5143  val_acc: 0.7308

# %% [markdown]
# ## Evaluate all metrics
#
# Same helper every notebook in this folder uses:
# [`evaluate_all_metrics`](../../../_handlers/evaluation.py) runs the model once over one split and
# prints **every** metric the training routines can produce — the medmnist Evaluator AUC/ACC plus
# accuracy, weighted precision / recall (sensitivity) / F1, per-class + average specificity,
# one-vs-rest AUC, the confusion matrix and a per-class report.
#
# `MCQCNNLogits` adapts the model to the contract `evaluate_all_metrics` expects (raw images in,
# logits out): it resizes each batch down to `img_size`, replicates the channels and feeds it
# through. `size=28` tells the medmnist `Evaluator` to score against the native-resolution `.npz`
# (the model never sees the `_224` variant). Set `split` to `'train'` or `'test'`.

# %%
split = 'test'   # 'train' or 'test'

eval_net = MCQCNNLogits(net, img_size=args.img_size, n_channels=args.n_channels)
eval_dataset = train_dataset if split == 'train' else test_dataset
metrics = evaluate_all_metrics(eval_net, eval_dataset, args.dataset, nb_classes=args.n_classes,
                               device=device, split=split, batch_size=args.batch_size, size=28)
# Out:
# 100%|██████████| 39/39 [00:01<00:00, 21.62it/s]
# [medmnist Evaluator]  auc: 0.7245  acc: 0.7308
#
# === test metrics (2 classes) ===
# accuracy            : 0.7308
# overall_accuracy    : 0.7308
# auc (ovr)           : 0.7245
# precision (weighted): 0.6827
# recall / sensitivity: 0.7308
# specificity (avg)   : 0.5451
# f1 (weighted)       : 0.6716
#
# per-class specificity: ['0.947', '0.143']
#
# confusion matrix:
# [[  6  36]
#  [  6 108]]
#
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22        42
#            1       0.75      0.95      0.84       114
#
#     accuracy                           0.73       156
#    macro avg       0.62      0.55      0.53       156
# weighted avg       0.68      0.73      0.67       156
